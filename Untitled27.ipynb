# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load dataset
imdb = tf.keras.datasets.imdb
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)

# Padding sequences to ensure uniform input length
X_train = pad_sequences(X_train, maxlen=200)
X_test = pad_sequences(X_test, maxlen=200)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential()
model.add(Embedding(input_dim=10000, output_dim=128, input_length=200))
model.add(LSTM(units=128, return_sequences=False))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3)
history = model.fit(X_train, y_train, validation_split=0.2, epochs=10, batch_size=64, callbacks=[early_stop])

loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss: {loss}, Accuracy: {accuracy}')

import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Hyperparameters to experiment with
embedding_dim = 128
lstm_units = [64, 128, 256]
dropout_rates = [0.2, 0.5]
learning_rates = [0.001, 0.0001]

# Placeholder for best model and performance
best_accuracy = 0
best_model = None

# Loop through different combinations of hyperparameters
for lstm_unit in lstm_units:
    for dropout_rate in dropout_rates:
        for learning_rate in learning_rates:
            print(f"Training model with LSTM units: {lstm_unit}, Dropout rate: {dropout_rate}, Learning rate: {learning_rate}")

            # Define the model
            model = Sequential()
            model.add(Embedding(input_dim=10000, output_dim=embedding_dim, input_length=200))
            model.add(LSTM(units=lstm_unit, return_sequences=False))
            model.add(Dropout(dropout_rate))
            model.add(Dense(units=1, activation='sigmoid'))

            # Compile the model with the current learning rate
            optimizer = Adam(learning_rate=learning_rate)
            model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

            # Set up early stopping
            early_stop = EarlyStopping(monitor='val_loss', patience=3)

            # Train the model
            history = model.fit(X_train, y_train, validation_split=0.2, epochs=10, batch_size=64, callbacks=[early_stop], verbose=0)

            # Evaluate the model
            loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
            print(f"Validation accuracy: {accuracy:.4f}")

            # Check if this model has the best performance so far
            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_model = model

# Output the best performance
print(f"Best validation accuracy: {best_accuracy:.4f}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 169s 528ms/step - accuracy: 0.6752 - loss: 0.5755 - val_accuracy: 0.8322 - val_loss: 0.3787
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 191s 495ms/step - accuracy: 0.8314 - loss: 0.4096 - val_accuracy: 0.8398 - val_loss: 0.3770
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 203s 499ms/step - accuracy: 0.8987 - loss: 0.2589 - val_accuracy: 0.8694 - val_loss: 0.3205
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 210s 524ms/step - accuracy: 0.9422 - loss: 0.1636 - val_accuracy: 0.8646 - val_loss: 0.3885
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 190s 486ms/step - accuracy: 0.9606 - loss: 0.1132 - val_accuracy: 0.8334 - val_loss: 0.4562
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 211s 516ms/step - accuracy: 0.9686 - loss: 0.0920 - val_accuracy: 0.8484 - val_loss: 0.4687
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.8464 - loss: 0.4817
# Loss: 0.47367629408836365, Accuracy: 0.847000002861023
# Training model with LSTM units: 64, Dropout rate: 0.2, Learning rate: 0.001
# Validation accuracy: 0.8436
# Training model with LSTM units: 64, Dropout rate: 0.2, Learning rate: 0.0001
# Validation accuracy: 0.8542
# Training model with LSTM units: 64, Dropout rate: 0.5, Learning rate: 0.001
# Validation accuracy: 0.8511
# Training model with LSTM units: 64, Dropout rate: 0.5, Learning rate: 0.0001
# Validation accuracy: 0.8644
# Training model with LSTM units: 128, Dropout rate: 0.2, Learning rate: 0.001
# Validation accuracy: 0.8267
# Training model with LSTM units: 128, Dropout rate: 0.2, Learning rate: 0.0001
# Validation accuracy: 0.8572
# Training model with LSTM units: 128, Dropout rate: 0.5, Learning rate: 0.001
# Validation accuracy: 0.8528
# Training model with LSTM units: 128, Dropout rate: 0.5, Learning rate: 0.0001
# Validation accuracy: 0.8559
# Training model with LSTM units: 256, Dropout rate: 0.2, Learning rate: 0.001
# Validation accuracy: 0.8520
# Training model with LSTM units: 256, Dropout rate: 0.2, Learning rate: 0.0001
# Validation accuracy: 0.8566
# Training model with LSTM units: 256, Dropout rate: 0.5, Learning rate: 0.001
# Validation accuracy: 0.8548
# Training model with LSTM units: 256, Dropout rate: 0.5, Learning rate: 0.0001
# Validation accuracy: 0.8678
# Best validation accuracy: 0.8678
